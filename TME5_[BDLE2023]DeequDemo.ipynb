# %% [markdown]
# * Master DAC - BDLE
# * Author: Mohamed-Amine Baazizi
# * Affiliation: LIP6 - Faculté des Sciences - Sorbonne Université
# * Email: mohamed-amine.baazizi@lip6.fr
# * October 2023

# %% [markdown]
# # Data quality verification

# %% [markdown]
# https://github.com/awslabs/deequ
#
# and its python-based version
#
# https://github.com/awslabs/python-deequ
#
# https://www.amazon.science/publications/automating-large-scale-data-quality-verification
#
# https://medium.com/codex/how-to-check-data-quality-in-pyspark-8a882e45bc95

# %% [markdown]
# ## Spark setup

# %%
# !pip install --upgrade -q pyspark==3.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.7/204.7 MB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.6/198.6 kB 21.7 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done

# %%
# !pyspark --version
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.10/dist-packages/pyspark/jars/spark-unsafe_2.12-3.0.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.0.0
#       /_/
#
# Using Scala version 2.12.10, OpenJDK 64-Bit Server VM, 11.0.20.1
# Branch HEAD
# Compiled by user ubuntu on 2020-06-06T11:32:25Z
# Revision 3fdfce3120f307147244e5eaf46d61419a723d50
# Url https://gitbox.apache.org/repos/asf/spark.git
# Type --help for more information.

# %%
import os
os.environ["SPARK_VERSION"] = "3.0"

# %%
# !pip install  --upgrade -q pydeequ

# %%
from pyspark.sql import SparkSession, Row
import pydeequ

spark = SparkSession.builder\
    .master("local")\
    .appName("pyDeequ")\
    .config("spark.jars.packages", pydeequ.deequ_maven_coord)\
    .config("spark.jars.excludes", pydeequ.f2j_maven_coord)\
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://5ba9c2c3468f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyDeequ</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %% [markdown]
# ## usage

# %% [markdown]
# ### examples for the official doc

# %%
df = spark.sparkContext.parallelize([
            Row(a="foo", b=1, c=5),
            Row(a="bar", b=2, c=6),
            Row(a="baz", b=3, c=None)]).toDF()
df.show()
# Out:
# +---+---+----+
# |  a|  b|   c|
# +---+---+----+
# |foo|  1|   5|
# |bar|  2|   6|
# |baz|  3|null|
# +---+---+----+

# %% [markdown]
# #### analyzers

# %%
from pydeequ.analyzers import *

analysisResult = AnalysisRunner(spark) \
                    .onData(df) \
                    .addAnalyzer(Size()) \
                    .addAnalyzer(Completeness("b")) \
                    .run()
analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)
analysisResult_df.show()
# Out:
# +-------+--------+------------+-----+
# | entity|instance|        name|value|
# +-------+--------+------------+-----+
# |Dataset|       *|        Size|  3.0|
# | Column|       b|Completeness|  1.0|
# +-------+--------+------------+-----+

# %% [markdown]
# => On a analysé deux métrique : la taille et la complétude de la colonne b.
#
#
# => La colonne b est complète (elle ne contient aucune valeur nulle) et le dataframe a 3 lignes.

# %% [markdown]
# #### profile

# %%
from pydeequ.profiles import *

result = ColumnProfilerRunner(spark) \
    .onData(df) \
    .run()

for col, profile in result.profiles.items():
    print(profile)
# Out:
# StandardProfiles for column: a: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 3,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 3
#     },
#     "histogram": [
#         [
#             "baz",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "foo",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "bar",
#             1,
#             0.3333333333333333
#         ]
#     ]
# }
# NumericProfiles for column: b: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 3,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "1",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "2",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "3",
#             1,
#             0.3333333333333333
#         ]
#     ],
#     "kll": "None",
#     "mean": 2.0,
#     "maximum": 3.0,
#     "minimum": 1.0,
#     "sum": 6.0,
#     "stdDev": 0.816496580927726,
#     "approxPercentiles": []
# }
# NumericProfiles for column: c: {
#     "completeness": 0.6666666666666666,
#     "approximateNumDistinctValues": 2,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "5",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "NullValue",
#             1,
#             0.3333333333333333
#         ],
#         [
#             "6",
#             1,
#             0.3333333333333333
#         ]
#     ],
#     "kll": "None",
#     "mean": 5.5,
#     "maximum": 6.0,
#     "minimum": 5.0,
#     "sum": 11.0,
#     "stdDev": 0.5,
#     "approxPercentiles": []
# }

# %% [markdown]
# #### constraint suggestion

# %%
from pydeequ.suggestions import *

suggestionResult = ConstraintSuggestionRunner(spark) \
             .onData(df) \
             .addConstraintRule(DEFAULT())\
             .run()

# Constraint Suggestions in JSON format
print(suggestionResult)
# Out:
# {'constraint_suggestions': [{'constraint_name': 'CompletenessConstraint(Completeness(b,None))', 'column_name': 'b', 'current_value': 'Completeness: 1.0', 'description': "'b' is not null", 'suggesting_rule': 'CompleteIfCompleteRule()', 'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint', 'code_for_constraint': '.isComplete("b")'}, {'constraint_name': "ComplianceConstraint(Compliance('b' has no negative values,b >= 0,None))", 'column_name': 'b', 'current_value': 'Minimum: 1.0', 'description': "'b' has no negative values", 'suggesting_rule': 'NonNegativeNumbersRule()', 'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint', 'code_for_constraint': '.isNonNegative("b")'}, {'constraint_name': 'UniquenessConstraint(Uniqueness(List(b),None))', 'column_name': 'b', 'current_value': 'ApproxDistinctness: 1.0', 'description': "'b' is unique", 'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()', 'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint', 'code_for_constraint': '.isUnique("b")'}, {'constraint_name': 'CompletenessConstraint(Completeness(a,None))', 'column_name': 'a', 'current_value': 'Completeness: 1.0', 'description': "'a' is not null", 'suggesting_rule': 'CompleteIfCompleteRule()', 'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint', 'code_for_constraint': '.isComplete("a")'}, {'constraint_name': 'UniquenessConstraint(Uniqueness(List(a),None))', 'column_name': 'a', 'current_value': 'ApproxDistinctness: 1.0', 'description': "'a' is unique", 'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()', 'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint', 'code_for_constraint': '.isUnique("a")'}, {'constraint_name': "ComplianceConstraint(Compliance('c' has no negative values,c >= 0,None))", 'column_name': 'c', 'current_value': 'Minimum: 5.0', 'description': "'c' has no negative values", 'suggesting_rule': 'NonNegativeNumbersRule()', 'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint', 'code_for_constraint': '.isNonNegative("c")'}, {'constraint_name': 'CompletenessConstraint(Completeness(c,None))', 'column_name': 'c', 'current_value': 'Completeness: 0.6666666666666666', 'description': "'c' has less than 87% missing values", 'suggesting_rule': 'RetainCompletenessRule()', 'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness', 'code_for_constraint': '.hasCompleteness("c", lambda x: x >= 0.13, "It should be above 0.13!")'}]}

# %% [markdown]
# #### constraint verification

# %%
from pydeequ.checks import *
from pydeequ.verification import *

check = Check(spark, CheckLevel.Warning, "Review Check")

def toto(x):
  return x>=3

checkResult = VerificationSuite(spark) \
    .onData(df) \
    .addCheck(
        check.hasSize(lambda x: x >= 3) \
        .hasSize(toto)\
        .hasMin("b", lambda x: x == 0) \
        .isComplete("c")  \
        .isUnique("a")  \
        .isContainedIn("a", ["foo", "bar", "baz"]) \
        .isNonNegative("b")) \
    .run()

checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult)
checkResult_df.show(truncate=False)
# Out:
# +------------+-----------+------------+-----------------------------------------------------------------------------------------------------------+-----------------+-------------------------------------------------------------------+
# |check       |check_level|check_status|constraint                                                                                                 |constraint_status|constraint_message                                                 |
# +------------+-----------+------------+-----------------------------------------------------------------------------------------------------------+-----------------+-------------------------------------------------------------------+
# |Review Check|Warning    |Warning     |SizeConstraint(Size(None))                                                                                 |Success          |                                                                   |
# |Review Check|Warning    |Warning     |SizeConstraint(Size(None))                                                                                 |Success          |                                                                   |
# |Review Check|Warning    |Warning     |MinimumConstraint(Minimum(b,None))                                                                         |Failure          |Value: 1.0 does not meet the constraint requirement!               |
# |Review Check|Warning    |Warning     |CompletenessConstraint(Completeness(c,None))                                                               |Failure          |Value: 0.6666666666666666 does not meet the constraint requirement!|
# |Review Check|Warning    |Warning     |UniquenessConstraint(Uniqueness(List(a),None))                                                             |Success          |                                                                   |
# |Review Check|Warning    |Warning     |ComplianceConstraint(Compliance(a contained in foo,bar,baz,`a` IS NULL OR `a` IN ('foo','bar','baz'),None))|Success          |                                                                   |
# |Review Check|Warning    |Warning     |ComplianceConstraint(Compliance(b is non-negative,COALESCE(CAST(b AS DECIMAL(20,10)), 0.0) >= 0,None))     |Success          |                                                                   |
# +------------+-----------+------------+-----------------------------------------------------------------------------------------------------------+-----------------+-------------------------------------------------------------------+

# %% [markdown]
# ### other examples

# %%
# !wget --no-verbose https://nuage.lip6.fr/s/89BG8HD9r3iE693/download/MLData.tgz -O /tmp/MLData.tgz
# Out:
# 2023-11-10 16:06:06 URL:https://nuage.lip6.fr/s/89BG8HD9r3iE693/download/MLData.tgz [19397838/19397838] -> "/tmp/MLData.tgz" [1]

# %%
# !tar -xzvf /tmp/MLData.tgz  --directory /tmp/
# Out:
# MLData/
# MLData/._loan.csv
# MLData/loan.csv
# MLData/autos.csv

# %%
# !rm  /tmp/MLData.tgz
# !rm /tmp/MLData/\._loan.csv
# !ls -hal /tmp/MLData
# Out:
# total 73M
# drwxr-xr-x 2  501 staff 4.0K Nov 10 16:06 .
# drwxrwxrwt 1 root root  4.0K Nov 10 16:06 ..
# -rw-r--r-- 1  501 staff  66M Jan  6  2022 autos.csv
# -rw-r--r-- 1  501 staff 6.8M Jan  6  2022 loan.csv

# %%
#load
dir = "/tmp/MLData/"
data =  spark.read\
            .format("csv").option("header", "true")\
            .option("inferSchema", "true")\
            .load(dir +"autos.csv")

# %%
data.count()
# Out:
# 371824

# %%
sample =data.sample(0.1)
sample.count()
# Out:
# 37494

# %%
sample.show()
# Out:
# +-------------------+--------------------+------+---------+-----+-------+-----------+------------------+---------+-------+--------+---------+-------------------+--------+-------------+-----------------+-------------------+------------+----------+-------------------+
# |        dateCrawled|                name|seller|offerType|price| abtest|vehicleType|yearOfRegistration|  gearbox|powerPS|   model|kilometer|monthOfRegistration|fuelType|        brand|notRepairedDamage|        dateCreated|nrOfPictures|postalCode|           lastSeen|
# +-------------------+--------------------+------+---------+-----+-------+-----------+------------------+---------+-------+--------+---------+-------------------+--------+-------------+-----------------+-------------------+------------+----------+-------------------+
# |2016-03-14 12:52:21|Jeep_Grand_Cherok...|privat|  Angebot| 9800|   test|        suv|              2004|automatik|    163|   grand|   125000|                  8|  diesel|         jeep|             null|2016-03-14 00:00:00|           0|     90480|2016-04-05 12:47:46|
# |2016-04-04 17:36:23|BMW_316i___e36_Li...|privat|  Angebot|  650|   test|  limousine|              1995|  manuell|    102|     3er|   150000|                 10|  benzin|          bmw|               ja|2016-04-04 00:00:00|           0|     33775|2016-04-06 19:17:07|
# |2016-03-21 18:54:38|VW_Derby_Bj_80__S...|privat|  Angebot|    0|   test|  limousine|              1980|  manuell|     50|  andere|    40000|                  7|  benzin|   volkswagen|             nein|2016-03-21 00:00:00|           0|     19348|2016-03-25 16:47:58|
# |2016-03-11 21:39:15|KA_Lufthansa_Edit...|privat|  Angebot|  450|   test| kleinwagen|              1910|     null|      0|      ka|     5000|                  0|  benzin|         ford|             null|2016-03-11 00:00:00|           0|     24148|2016-03-19 08:46:47|
# |2016-03-28 17:50:15|Renault_Kangoo_1....|privat|  Angebot| 1500|   test|       null|              2016|     null|      0|  kangoo|   150000|                  1|  diesel|      renault|             nein|2016-03-28 00:00:00|           0|     46483|2016-03-30 09:18:02|
# |2016-03-25 15:50:30|Mercedes_Camper_D407|privat|  Angebot| 1500|   test|        bus|              1984|  manuell|     70|  andere|   150000|                  8|  diesel|mercedes_benz|             nein|2016-03-25 00:00:00|           0|     22767|2016-03-27 03:17:02|
# |2016-03-10 20:53:19|Seat_inca_1.9SDI_...|privat|  Angebot| 2399|   test|       null|              2018|  manuell|     64|  andere|   125000|                  3|    null|         seat|             nein|2016-03-10 00:00:00|           0|     33397|2016-03-25 10:17:37|
# |2016-03-21 12:47:55|Honda_HRV_reservi...|privat|  Angebot| 2100|control|        suv|              2000|  manuell|    105|  andere|   150000|                  8|  benzin|        honda|             nein|2016-02-09 00:00:00|           0|     85244|2016-03-31 16:46:09|
# |2016-04-01 11:56:40|Opel_astra_g_coup...|privat|  Angebot| 1200|   test|      coupe|              2001|     null|      0|   astra|   150000|                  0|    null|         opel|             null|2016-04-01 00:00:00|           0|     47249|2016-04-07 08:46:07|
# |2016-03-22 17:45:41|Mercedes_Benz_C_1...|privat|  Angebot| 7999|control|      kombi|              2008|  manuell|    156|c_klasse|   150000|                 10|  benzin|mercedes_benz|             nein|2016-03-22 00:00:00|           0|     83355|2016-03-25 09:47:43|
# |2016-03-09 21:46:09|     Ford_Escort_CLX|privat|  Angebot|  600|   test|  limousine|              1994|  manuell|     75|  escort|   100000|                  6|  benzin|         ford|               ja|2016-03-09 00:00:00|           0|     37359|2016-04-05 23:44:25|
# |2016-03-23 18:59:37|Mercedes_Benz_C_2...|privat|  Angebot| 3300|   test|      kombi|              2005|  manuell|    150|c_klasse|   150000|                  9|  diesel|mercedes_benz|               ja|2016-03-23 00:00:00|           0|     29221|2016-03-23 18:59:37|
# |2016-03-08 13:49:57|Fiesta_Titanium_1.25|privat|  Angebot| 6800|control| kleinwagen|              2009|  manuell|     82|  fiesta|    60000|                 12|  benzin|         ford|             nein|2016-03-08 00:00:00|           0|     51065|2016-04-05 19:18:01|
# |2016-03-15 17:41:31|Audi_A4_B5_1_6_Liter|privat|  Angebot|  499|control|  limousine|              1995|  manuell|    101|      a4|   150000|                  5|  benzin|         audi|             null|2016-03-15 00:00:00|           0|     85414|2016-03-22 20:48:22|
# |2016-03-26 07:36:20|verkaufe_Mercedes...|privat|  Angebot|  900|   test|      kombi|              1999|  manuell|    125|c_klasse|   150000|                  7|  diesel|mercedes_benz|             nein|2016-03-26 00:00:00|           0|     37130|2016-03-29 11:44:47|
# |2016-03-26 15:47:58|Opel_Astra_Twin_T...|privat|  Angebot| 8599|   test|     cabrio|              2006|  manuell|    200|   astra|   125000|                  9|  benzin|         opel|             nein|2016-03-26 00:00:00|           0|     79761|2016-04-06 04:15:35|
# |2016-03-20 10:54:17|VW_Golf_6_1.4_Com...|privat|  Angebot| 8000|control|       null|              2009|  manuell|      0|    golf|   100000|                 10|  benzin|   volkswagen|             nein|2016-03-20 00:00:00|           0|     94139|2016-04-06 07:45:51|
# |2016-04-05 09:55:37|BMW_330d_schadow_...|privat|  Angebot| 4200|control|      kombi|              2003|automatik|    204|     3er|   150000|                  1|  diesel|          bmw|             nein|2016-04-05 00:00:00|           0|     53757|2016-04-07 13:16:46|
# |2016-04-01 10:54:38|        BMW_E34_518I|privat|  Angebot|  950|control|  limousine|              1995|  manuell|    115|     5er|   150000|                  0|  benzin|          bmw|             null|2016-04-01 00:00:00|           0|     27751|2016-04-07 07:46:00|
# |2016-03-24 15:38:18|Opel_Astra_J_Desi...|privat|  Angebot|11000|   test|  limousine|              2012|  manuell|    131|   astra|    70000|                  3|  diesel|         opel|             nein|2016-03-24 00:00:00|           0|     34613|2016-04-05 11:56:32|
# +-------------------+--------------------+------+---------+-----+-------+-----------+------------------+---------+-------+--------+---------+-------------------+--------+-------------+-----------------+-------------------+------------+----------+-------------------+
# only showing top 20 rows

# %%
sample.printSchema()
# Out:
# root
#  |-- dateCrawled: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- seller: string (nullable = true)
#  |-- offerType: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- abtest: string (nullable = true)
#  |-- vehicleType: string (nullable = true)
#  |-- yearOfRegistration: integer (nullable = true)
#  |-- gearbox: string (nullable = true)
#  |-- powerPS: integer (nullable = true)
#  |-- model: string (nullable = true)
#  |-- kilometer: integer (nullable = true)
#  |-- monthOfRegistration: integer (nullable = true)
#  |-- fuelType: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- notRepairedDamage: string (nullable = true)
#  |-- dateCreated: string (nullable = true)
#  |-- nrOfPictures: integer (nullable = true)
#  |-- postalCode: integer (nullable = true)
#  |-- lastSeen: string (nullable = true)

# %% [markdown]
# #### Analyzers

# %%
# set these variables
_data = sample
_colName = "vehicleType"

#reuse from tutorial
from pydeequ.analyzers import *

analysisResult = AnalysisRunner(spark) \
                    .onData(_data) \
                    .addAnalyzer(Size()) \
                    .addAnalyzer(Completeness(_colName)) \
                    .addAnalyzer(CountDistinct(_colName)) \
                    .addAnalyzer(Distinctness(_colName))\
                    .run()

# %%
analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)
analysisResult_df.show(truncate=False)
# Out:
# +-------+-----------+-------------+---------------------+
# |entity |instance   |name         |value                |
# +-------+-----------+-------------+---------------------+
# |Dataset|*          |Size         |37494.0              |
# |Column |vehicleType|Completeness |0.8984104123326399   |
# |Column |vehicleType|CountDistinct|8.0                  |
# |Column |vehicleType|Distinctness |2.3749443372420958E-4|
# +-------+-----------+-------------+---------------------+

# %% [markdown]
# Now consider more metrics (consistency)

# %%
_targetColName = 'price'
_otherColName = 'powerPS'
analysisResult = AnalysisRunner(spark) \
                    .onData(_data) \
                    .addAnalyzer(Entropy(_colName))\
                    .addAnalyzer(Correlation(_otherColName,_targetColName))\
                    .run()

# %%
analysisResult_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysisResult)
analysisResult_df.show(truncate=False)
# Out:
# +-----------+-------------+-----------+--------------------+
# |entity     |instance     |name       |value               |
# +-----------+-------------+-----------+--------------------+
# |Mutlicolumn|powerPS,price|Correlation|3.988948607907948E-4|
# |Column     |vehicleType  |Entropy    |1.7703514405647869  |
# +-----------+-------------+-----------+--------------------+

# %% [markdown]
# #### profile

# %%
from pydeequ.profiles import *

result = ColumnProfilerRunner(spark) \
    .onData(_data) \
    .run()

# %%
# for col, profile in result.profiles.items():
#     print(profile)

# %%
result.columnProfileClasses
# Out:
# {'StandardColumnProfile': pydeequ.profiles.StandardColumnProfile,
#  'NumericColumnProfile': pydeequ.profiles.NumericColumnProfile}

# %%
result.profiles
# Out:
# {'lastSeen': <pydeequ.profiles.StandardColumnProfile at 0x7a77deadf580>,
#  'name': <pydeequ.profiles.StandardColumnProfile at 0x7a77deaddfc0>,
#  'yearOfRegistration': <pydeequ.profiles.NumericColumnProfile at 0x7a77deadc940>,
#  'model': <pydeequ.profiles.StandardColumnProfile at 0x7a77deade8c0>,
#  'abtest': <pydeequ.profiles.StandardColumnProfile at 0x7a77deadfb50>,
#  'powerPS': <pydeequ.profiles.NumericColumnProfile at 0x7a77dec12680>,
#  'fuelType': <pydeequ.profiles.StandardColumnProfile at 0x7a77deadf790>,
#  'notRepairedDamage': <pydeequ.profiles.StandardColumnProfile at 0x7a77deaddb10>,
#  'price': <pydeequ.profiles.NumericColumnProfile at 0x7a77dec13760>,
#  'vehicleType': <pydeequ.profiles.StandardColumnProfile at 0x7a77deadd720>,
#  'dateCrawled': <pydeequ.profiles.StandardColumnProfile at 0x7a77deadcf10>,
#  'offerType': <pydeequ.profiles.StandardColumnProfile at 0x7a77dec11840>,
#  'gearbox': <pydeequ.profiles.StandardColumnProfile at 0x7a77dec13880>,
#  'monthOfRegistration': <pydeequ.profiles.NumericColumnProfile at 0x7a77deadf4f0>,
#  'brand': <pydeequ.profiles.StandardColumnProfile at 0x7a77dec12bc0>,
#  'postalCode': <pydeequ.profiles.NumericColumnProfile at 0x7a77dec125f0>,
#  'dateCreated': <pydeequ.profiles.StandardColumnProfile at 0x7a77dec12ad0>,
#  'nrOfPictures': <pydeequ.profiles.NumericColumnProfile at 0x7a77deadc7f0>,
#  'kilometer': <pydeequ.profiles.NumericColumnProfile at 0x7a77dec12140>,
#  'seller': <pydeequ.profiles.StandardColumnProfile at 0x7a77deadf5e0>}

# %%
ex_result = ColumnProfilerRunner(spark) \
    .onData(_data.select('name','powerPs')) \
    .run()

# %%
for col, profile in ex_result.profiles.items():
    print(profile)
# Out:
# StandardProfiles for column: name: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 30158,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 11,
#         "Unknown": 0,
#         "String": 37483
#     },
#     "histogram": null
# }
# NumericProfiles for column: powerPs: {
#     "completeness": 0.9999733290659839,
#     "approximateNumDistinctValues": 408,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 115.87408316219027,
#     "maximum": 20000.0,
#     "minimum": 0.0,
#     "sum": 4344467.0,
#     "stdDev": 212.6371052170788,
#     "approxPercentiles": []
# }

# %% [markdown]
# ##### [TODO] import the JSON object to a DF to facilitate its processing

# %%
type(_data)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# #### constraint suggestion

# %%
from pydeequ.suggestions import *

suggestionResult = ConstraintSuggestionRunner(spark) \
             .onData(_data) \
             .addConstraintRule(DEFAULT()) \
             .run()

# Constraint Suggestions in JSON format
#print(suggestionResult)

# %%
suggestionResult
# Out:
# {'constraint_suggestions': [{'constraint_name': 'CompletenessConstraint(Completeness(lastSeen,None))',
#    'column_name': 'lastSeen',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'lastSeen' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("lastSeen", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(name,None))',
#    'column_name': 'name',
#    'current_value': 'Completeness: 1.0',
#    'description': "'name' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("name")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('yearOfRegistration' has value range '2000', '1999', '2005', '2006', '2003', '2001', '2004', '2002', '1998', '2007', '2008', '1997', '2009', '2011', '2010', '1996', '2017', '2016', '1995', '2012', '2013', '1994' for at least 90.0% of values,`yearOfRegistration` IN ('2000', '1999', '2005', '2006', '2003', '2001', '2004', '2002', '1998', '2007', '2008', '1997', '2009', '2011', '2010', '1996', '2017', '2016', '1995', '2012', '2013', '1994'),None))",
#    'column_name': 'yearOfRegistration',
#    'current_value': 'Compliance: 0.906785085613698',
#    'description': "'yearOfRegistration' has value range '2000', '1999', '2005', '2006', '2003', '2001', '2004', '2002', '1998', '2007', '2008', '1997', '2009', '2011', '2010', '1996', '2017', '2016', '1995', '2012', '2013', '1994' for at least 90.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("yearOfRegistration", ["2000", "1999", "2005", "2006", "2003", "2001", "2004", "2002", "1998", "2007", "2008", "1997", "2009", "2011", "2010", "1996", "2017", "2016", "1995", "2012", "2013", "1994"], lambda x: x >= 0.9, "It should be above 0.9!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('yearOfRegistration' has no negative values,yearOfRegistration >= 0,None))",
#    'column_name': 'yearOfRegistration',
#    'current_value': 'Minimum: 1000.0',
#    'description': "'yearOfRegistration' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("yearOfRegistration")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(yearOfRegistration,None))',
#    'column_name': 'yearOfRegistration',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'yearOfRegistration' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("yearOfRegistration", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(model,None))',
#    'column_name': 'model',
#    'current_value': 'Completeness: 0.9441777351042834',
#    'description': "'model' has less than 6% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("model", lambda x: x >= 0.94, "It should be above 0.94!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('abtest' has value range 'test', 'control' for at least 99.0% of values,`abtest` IN ('test', 'control'),None))",
#    'column_name': 'abtest',
#    'current_value': 'Compliance: 0.9999733290659838',
#    'description': "'abtest' has value range 'test', 'control' for at least 99.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("abtest", ["test", "control"], lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(abtest,None))',
#    'column_name': 'abtest',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'abtest' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("abtest", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('powerPS' has no negative values,powerPS >= 0,None))",
#    'column_name': 'powerPS',
#    'current_value': 'Minimum: 0.0',
#    'description': "'powerPS' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("powerPS")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(powerPS,None))',
#    'column_name': 'powerPS',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'powerPS' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("powerPS", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('fuelType' has value range 'benzin', 'diesel', 'lpg', 'cng', 'hybrid', 'andere', 'elektro',`fuelType` IN ('benzin', 'diesel', 'lpg', 'cng', 'hybrid', 'andere', 'elektro'),None))",
#    'column_name': 'fuelType',
#    'current_value': 'Compliance: 1',
#    'description': "'fuelType' has value range 'benzin', 'diesel', 'lpg', 'cng', 'hybrid', 'andere', 'elektro'",
#    'suggesting_rule': 'CategoricalRangeRule()',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("fuelType", ["benzin", "diesel", "lpg", "cng", "hybrid", "andere", "elektro"])'},
#   {'constraint_name': "ComplianceConstraint(Compliance('fuelType' has value range 'benzin', 'diesel' for at least 98.0% of values,`fuelType` IN ('benzin', 'diesel'),None))",
#    'column_name': 'fuelType',
#    'current_value': 'Compliance: 0.9820237904731424',
#    'description': "'fuelType' has value range 'benzin', 'diesel' for at least 98.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("fuelType", ["benzin", "diesel"], lambda x: x >= 0.98, "It should be above 0.98!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(fuelType,None))',
#    'column_name': 'fuelType',
#    'current_value': 'Completeness: 0.9089454312690031',
#    'description': "'fuelType' has less than 9% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("fuelType", lambda x: x >= 0.9, "It should be above 0.9!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('notRepairedDamage' has value range 'nein', 'ja',`notRepairedDamage` IN ('nein', 'ja'),None))",
#    'column_name': 'notRepairedDamage',
#    'current_value': 'Compliance: 1',
#    'description': "'notRepairedDamage' has value range 'nein', 'ja'",
#    'suggesting_rule': 'CategoricalRangeRule()',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("notRepairedDamage", ["nein", "ja"])'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(notRepairedDamage,None))',
#    'column_name': 'notRepairedDamage',
#    'current_value': 'Completeness: 0.8081826425561424',
#    'description': "'notRepairedDamage' has less than 19% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("notRepairedDamage", lambda x: x >= 0.8, "It should be above 0.8!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('price' has no negative values,price >= 0,None))",
#    'column_name': 'price',
#    'current_value': 'Minimum: 0.0',
#    'description': "'price' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("price")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(price,None))',
#    'column_name': 'price',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'price' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("price", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('vehicleType' has value range 'limousine', 'kleinwagen', 'kombi', 'bus', 'cabrio', 'coupe', 'suv', 'andere',`vehicleType` IN ('limousine', 'kleinwagen', 'kombi', 'bus', 'cabrio', 'coupe', 'suv', 'andere'),None))",
#    'column_name': 'vehicleType',
#    'current_value': 'Compliance: 1',
#    'description': "'vehicleType' has value range 'limousine', 'kleinwagen', 'kombi', 'bus', 'cabrio', 'coupe', 'suv', 'andere'",
#    'suggesting_rule': 'CategoricalRangeRule()',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("vehicleType", ["limousine", "kleinwagen", "kombi", "bus", "cabrio", "coupe", "suv", "andere"])'},
#   {'constraint_name': "ComplianceConstraint(Compliance('vehicleType' has value range 'limousine', 'kleinwagen', 'kombi', 'bus', 'cabrio' for at least 89.0% of values,`vehicleType` IN ('limousine', 'kleinwagen', 'kombi', 'bus', 'cabrio'),None))",
#    'column_name': 'vehicleType',
#    'current_value': 'Compliance: 0.9003307195817999',
#    'description': "'vehicleType' has value range 'limousine', 'kleinwagen', 'kombi', 'bus', 'cabrio' for at least 89.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("vehicleType", ["limousine", "kleinwagen", "kombi", "bus", "cabrio"], lambda x: x >= 0.89, "It should be above 0.89!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(vehicleType,None))',
#    'column_name': 'vehicleType',
#    'current_value': 'Completeness: 0.8984104123326399',
#    'description': "'vehicleType' has less than 10% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("vehicleType", lambda x: x >= 0.89, "It should be above 0.89!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(dateCrawled,None))',
#    'column_name': 'dateCrawled',
#    'current_value': 'Completeness: 1.0',
#    'description': "'dateCrawled' is not null",
#    'suggesting_rule': 'CompleteIfCompleteRule()',
#    'rule_description': 'If a column is complete in the sample, we suggest a NOT NULL constraint',
#    'code_for_constraint': '.isComplete("dateCrawled")'},
#   {'constraint_name': 'UniquenessConstraint(Uniqueness(List(dateCrawled),None))',
#    'column_name': 'dateCrawled',
#    'current_value': 'ApproxDistinctness: 1.06299674614605',
#    'description': "'dateCrawled' is unique",
#    'suggesting_rule': 'UniqueIfApproximatelyUniqueRule()',
#    'rule_description': 'If the ratio of approximate num distinct values in a column is close to the number of records (within the error of the HLL sketch), we suggest a UNIQUE constraint',
#    'code_for_constraint': '.isUnique("dateCrawled")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('offerType' has value range 'Angebot' for at least 99.0% of values,`offerType` IN ('Angebot'),None))",
#    'column_name': 'offerType',
#    'current_value': 'Compliance: 0.9999199871979517',
#    'description': "'offerType' has value range 'Angebot' for at least 99.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("offerType", ["Angebot"], lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(offerType,None))',
#    'column_name': 'offerType',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'offerType' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("offerType", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('gearbox' has value range 'manuell', 'automatik',`gearbox` IN ('manuell', 'automatik'),None))",
#    'column_name': 'gearbox',
#    'current_value': 'Compliance: 1',
#    'description': "'gearbox' has value range 'manuell', 'automatik'",
#    'suggesting_rule': 'CategoricalRangeRule()',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("gearbox", ["manuell", "automatik"])'},
#   {'constraint_name': "ComplianceConstraint(Compliance('gearbox' has value range 'manuell', 'automatik' for at least 94.0% of values,`gearbox` IN ('manuell', 'automatik'),None))",
#    'column_name': 'gearbox',
#    'current_value': 'Compliance: 0.9450045340587827',
#    'description': "'gearbox' has value range 'manuell', 'automatik' for at least 94.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("gearbox", ["manuell", "automatik"], lambda x: x >= 0.94, "It should be above 0.94!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(gearbox,None))',
#    'column_name': 'gearbox',
#    'current_value': 'Completeness: 0.9450045340587827',
#    'description': "'gearbox' has less than 6% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("gearbox", lambda x: x >= 0.94, "It should be above 0.94!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('monthOfRegistration' has value range '0', '3', '6', '5', '4', '7', '10', '11', '12', '8', '9', '1', '2',`monthOfRegistration` IN ('0', '3', '6', '5', '4', '7', '10', '11', '12', '8', '9', '1', '2'),None))",
#    'column_name': 'monthOfRegistration',
#    'current_value': 'Compliance: 1',
#    'description': "'monthOfRegistration' has value range '0', '3', '6', '5', '4', '7', '10', '11', '12', '8', '9', '1', '2'",
#    'suggesting_rule': 'CategoricalRangeRule()',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("monthOfRegistration", ["0", "3", "6", "5", "4", "7", "10", "11", "12", "8", "9", "1", "2"])'},
#   {'constraint_name': "ComplianceConstraint(Compliance('monthOfRegistration' has value range '0', '3', '6', '5', '4', '7', '10', '11', '12', '8', '9', '1' for at least 93.0% of values,`monthOfRegistration` IN ('0', '3', '6', '5', '4', '7', '10', '11', '12', '8', '9', '1'),None))",
#    'column_name': 'monthOfRegistration',
#    'current_value': 'Compliance: 0.9385234970928682',
#    'description': "'monthOfRegistration' has value range '0', '3', '6', '5', '4', '7', '10', '11', '12', '8', '9', '1' for at least 93.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("monthOfRegistration", ["0", "3", "6", "5", "4", "7", "10", "11", "12", "8", "9", "1"], lambda x: x >= 0.93, "It should be above 0.93!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('monthOfRegistration' has no negative values,monthOfRegistration >= 0,None))",
#    'column_name': 'monthOfRegistration',
#    'current_value': 'Minimum: 0.0',
#    'description': "'monthOfRegistration' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("monthOfRegistration")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(monthOfRegistration,None))',
#    'column_name': 'monthOfRegistration',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'monthOfRegistration' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("monthOfRegistration", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('brand' has value range 'volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford', 'renault', 'peugeot', 'fiat', 'seat', 'citroen', 'mazda', 'skoda', 'smart', 'nissan', 'toyota', 'sonstige_autos', 'hyundai', 'mini', 'volvo', 'mitsubishi', 'kia', 'honda', 'alfa_romeo', 'suzuki', 'porsche', 'chevrolet', 'chrysler', 'dacia', 'daihatsu', 'jeep', 'subaru', 'land_rover', 'jaguar', 'trabant', 'rover', 'lancia', 'daewoo', 'saab', 'lada',`brand` IN ('volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford', 'renault', 'peugeot', 'fiat', 'seat', 'citroen', 'mazda', 'skoda', 'smart', 'nissan', 'toyota', 'sonstige_autos', 'hyundai', 'mini', 'volvo', 'mitsubishi', 'kia', 'honda', 'alfa_romeo', 'suzuki', 'porsche', 'chevrolet', 'chrysler', 'dacia', 'daihatsu', 'jeep', 'subaru', 'land_rover', 'jaguar', 'trabant', 'rover', 'lancia', 'daewoo', 'saab', 'lada'),None))",
#    'column_name': 'brand',
#    'current_value': 'Compliance: 1',
#    'description': "'brand' has value range 'volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford', 'renault', 'peugeot', 'fiat', 'seat', 'citroen', 'mazda', 'skoda', 'smart', 'nissan', 'toyota', 'sonstige_autos', 'hyundai', 'mini', 'volvo', 'mitsubishi', 'kia', 'honda', 'alfa_romeo', 'suzuki', 'porsche', 'chevrolet', 'chrysler', 'dacia', 'daihatsu', 'jeep', 'subaru', 'land_rover', 'jaguar', 'trabant', 'rover', 'lancia', 'daewoo', 'saab', 'lada'",
#    'suggesting_rule': 'CategoricalRangeRule()',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("brand", ["volkswagen", "opel", "bmw", "mercedes_benz", "audi", "ford", "renault", "peugeot", "fiat", "seat", "citroen", "mazda", "skoda", "smart", "nissan", "toyota", "sonstige_autos", "hyundai", "mini", "volvo", "mitsubishi", "kia", "honda", "alfa_romeo", "suzuki", "porsche", "chevrolet", "chrysler", "dacia", "daihatsu", "jeep", "subaru", "land_rover", "jaguar", "trabant", "rover", "lancia", "daewoo", "saab", "lada"])'},
#   {'constraint_name': "ComplianceConstraint(Compliance('brand' has value range 'volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford', 'renault', 'peugeot', 'fiat', 'seat', 'citroen', 'mazda', 'skoda', 'smart', 'nissan', 'toyota', 'sonstige_autos' for at least 89.0% of values,`brand` IN ('volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford', 'renault', 'peugeot', 'fiat', 'seat', 'citroen', 'mazda', 'skoda', 'smart', 'nissan', 'toyota', 'sonstige_autos'),None))",
#    'column_name': 'brand',
#    'current_value': 'Compliance: 0.900624099855977',
#    'description': "'brand' has value range 'volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford', 'renault', 'peugeot', 'fiat', 'seat', 'citroen', 'mazda', 'skoda', 'smart', 'nissan', 'toyota', 'sonstige_autos' for at least 89.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("brand", ["volkswagen", "opel", "bmw", "mercedes_benz", "audi", "ford", "renault", "peugeot", "fiat", "seat", "citroen", "mazda", "skoda", "smart", "nissan", "toyota", "sonstige_autos"], lambda x: x >= 0.89, "It should be above 0.89!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(brand,None))',
#    'column_name': 'brand',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'brand' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("brand", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('postalCode' has no negative values,postalCode >= 0,None))",
#    'column_name': 'postalCode',
#    'current_value': 'Minimum: 1067.0',
#    'description': "'postalCode' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("postalCode")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(postalCode,None))',
#    'column_name': 'postalCode',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'postalCode' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("postalCode", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('dateCreated' has value range '2016-04-03 00:00:00', '2016-04-04 00:00:00', '2016-03-20 00:00:00', '2016-04-02 00:00:00', '2016-03-19 00:00:00', '2016-03-12 00:00:00', '2016-03-14 00:00:00', '2016-04-01 00:00:00', '2016-03-21 00:00:00', '2016-03-07 00:00:00', '2016-03-29 00:00:00', '2016-03-10 00:00:00', '2016-03-30 00:00:00', '2016-03-15 00:00:00', '2016-03-28 00:00:00', '2016-03-08 00:00:00', '2016-03-22 00:00:00', '2016-03-25 00:00:00', '2016-03-31 00:00:00', '2016-03-11 00:00:00', '2016-03-09 00:00:00', '2016-03-26 00:00:00', '2016-03-23 00:00:00', '2016-03-17 00:00:00', '2016-03-27 00:00:00', '2016-03-16 00:00:00', '2016-03-24 00:00:00' for at least 90.0% of values,`dateCreated` IN ('2016-04-03 00:00:00', '2016-04-04 00:00:00', '2016-03-20 00:00:00', '2016-04-02 00:00:00', '2016-03-19 00:00:00', '2016-03-12 00:00:00', '2016-03-14 00:00:00', '2016-04-01 00:00:00', '2016-03-21 00:00:00', '2016-03-07 00:00:00', '2016-03-29 00:00:00', '2016-03-10 00:00:00', '2016-03-30 00:00:00', '2016-03-15 00:00:00', '2016-03-28 00:00:00', '2016-03-08 00:00:00', '2016-03-22 00:00:00', '2016-03-25 00:00:00', '2016-03-31 00:00:00', '2016-03-11 00:00:00', '2016-03-09 00:00:00', '2016-03-26 00:00:00', '2016-03-23 00:00:00', '2016-03-17 00:00:00', '2016-03-27 00:00:00', '2016-03-16 00:00:00', '2016-03-24 00:00:00'),None))",
#    'column_name': 'dateCreated',
#    'current_value': 'Compliance: 0.910172294233744',
#    'description': "'dateCreated' has value range '2016-04-03 00:00:00', '2016-04-04 00:00:00', '2016-03-20 00:00:00', '2016-04-02 00:00:00', '2016-03-19 00:00:00', '2016-03-12 00:00:00', '2016-03-14 00:00:00', '2016-04-01 00:00:00', '2016-03-21 00:00:00', '2016-03-07 00:00:00', '2016-03-29 00:00:00', '2016-03-10 00:00:00', '2016-03-30 00:00:00', '2016-03-15 00:00:00', '2016-03-28 00:00:00', '2016-03-08 00:00:00', '2016-03-22 00:00:00', '2016-03-25 00:00:00', '2016-03-31 00:00:00', '2016-03-11 00:00:00', '2016-03-09 00:00:00', '2016-03-26 00:00:00', '2016-03-23 00:00:00', '2016-03-17 00:00:00', '2016-03-27 00:00:00', '2016-03-16 00:00:00', '2016-03-24 00:00:00' for at least 90.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("dateCreated", ["2016-04-03 00:00:00", "2016-04-04 00:00:00", "2016-03-20 00:00:00", "2016-04-02 00:00:00", "2016-03-19 00:00:00", "2016-03-12 00:00:00", "2016-03-14 00:00:00", "2016-04-01 00:00:00", "2016-03-21 00:00:00", "2016-03-07 00:00:00", "2016-03-29 00:00:00", "2016-03-10 00:00:00", "2016-03-30 00:00:00", "2016-03-15 00:00:00", "2016-03-28 00:00:00", "2016-03-08 00:00:00", "2016-03-22 00:00:00", "2016-03-25 00:00:00", "2016-03-31 00:00:00", "2016-03-11 00:00:00", "2016-03-09 00:00:00", "2016-03-26 00:00:00", "2016-03-23 00:00:00", "2016-03-17 00:00:00", "2016-03-27 00:00:00", "2016-03-16 00:00:00", "2016-03-24 00:00:00"], lambda x: x >= 0.9, "It should be above 0.9!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(dateCreated,None))',
#    'column_name': 'dateCreated',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'dateCreated' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("dateCreated", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('nrOfPictures' has no negative values,nrOfPictures >= 0,None))",
#    'column_name': 'nrOfPictures',
#    'current_value': 'Minimum: 0.0',
#    'description': "'nrOfPictures' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("nrOfPictures")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(nrOfPictures,None))',
#    'column_name': 'nrOfPictures',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'nrOfPictures' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("nrOfPictures", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('kilometer' has value range '150000', '125000', '100000', '90000', '80000', '70000', '60000', '50000', '5000', '40000', '30000', '20000', '10000',`kilometer` IN ('150000', '125000', '100000', '90000', '80000', '70000', '60000', '50000', '5000', '40000', '30000', '20000', '10000'),None))",
#    'column_name': 'kilometer',
#    'current_value': 'Compliance: 1',
#    'description': "'kilometer' has value range '150000', '125000', '100000', '90000', '80000', '70000', '60000', '50000', '5000', '40000', '30000', '20000', '10000'",
#    'suggesting_rule': 'CategoricalRangeRule()',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("kilometer", ["150000", "125000", "100000", "90000", "80000", "70000", "60000", "50000", "5000", "40000", "30000", "20000", "10000"])'},
#   {'constraint_name': "ComplianceConstraint(Compliance('kilometer' has value range '150000', '125000', '100000', '90000', '80000', '70000', '60000' for at least 90.0% of values,`kilometer` IN ('150000', '125000', '100000', '90000', '80000', '70000', '60000'),None))",
#    'column_name': 'kilometer',
#    'current_value': 'Compliance: 0.9054248679788766',
#    'description': "'kilometer' has value range '150000', '125000', '100000', '90000', '80000', '70000', '60000' for at least 90.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("kilometer", ["150000", "125000", "100000", "90000", "80000", "70000", "60000"], lambda x: x >= 0.9, "It should be above 0.9!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('kilometer' has no negative values,kilometer >= 0,None))",
#    'column_name': 'kilometer',
#    'current_value': 'Minimum: 5000.0',
#    'description': "'kilometer' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("kilometer")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(kilometer,None))',
#    'column_name': 'kilometer',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'kilometer' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("kilometer", lambda x: x >= 0.99, "It should be above 0.99!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(seller,None))',
#    'column_name': 'seller',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'seller' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("seller", lambda x: x >= 0.99, "It should be above 0.99!")'}]}

# %%
from pydeequ.suggestions import *

suggestionResult = ConstraintSuggestionRunner(spark) \
             .onData(_data.select('fuelType','powerPs')) \
             .addConstraintRule(DEFAULT()) \
             .run()

# Constraint Suggestions in JSON format
#print(suggestionResult)

# %%
suggestionResult
# Out:
# {'constraint_suggestions': [{'constraint_name': "ComplianceConstraint(Compliance('fuelType' has value range 'benzin', 'diesel', 'lpg', 'cng', 'hybrid', 'andere', 'elektro',`fuelType` IN ('benzin', 'diesel', 'lpg', 'cng', 'hybrid', 'andere', 'elektro'),None))",
#    'column_name': 'fuelType',
#    'current_value': 'Compliance: 1',
#    'description': "'fuelType' has value range 'benzin', 'diesel', 'lpg', 'cng', 'hybrid', 'andere', 'elektro'",
#    'suggesting_rule': 'CategoricalRangeRule()',
#    'rule_description': 'If we see a categorical range for a column, we suggest an IS IN (...) constraint',
#    'code_for_constraint': '.isContainedIn("fuelType", ["benzin", "diesel", "lpg", "cng", "hybrid", "andere", "elektro"])'},
#   {'constraint_name': "ComplianceConstraint(Compliance('fuelType' has value range 'benzin', 'diesel' for at least 98.0% of values,`fuelType` IN ('benzin', 'diesel'),None))",
#    'column_name': 'fuelType',
#    'current_value': 'Compliance: 0.9820237904731424',
#    'description': "'fuelType' has value range 'benzin', 'diesel' for at least 98.0% of values",
#    'suggesting_rule': 'FractionalCategoricalRangeRule(0.9)',
#    'rule_description': 'If we see a categorical range for most values in a column, we suggest an IS IN (...) constraint that should hold for most values',
#    'code_for_constraint': '.isContainedIn("fuelType", ["benzin", "diesel"], lambda x: x >= 0.98, "It should be above 0.98!")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(fuelType,None))',
#    'column_name': 'fuelType',
#    'current_value': 'Completeness: 0.9089454312690031',
#    'description': "'fuelType' has less than 9% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("fuelType", lambda x: x >= 0.9, "It should be above 0.9!")'},
#   {'constraint_name': "ComplianceConstraint(Compliance('powerPs' has no negative values,powerPs >= 0,None))",
#    'column_name': 'powerPs',
#    'current_value': 'Minimum: 0.0',
#    'description': "'powerPs' has no negative values",
#    'suggesting_rule': 'NonNegativeNumbersRule()',
#    'rule_description': 'If we see only non-negative numbers in a column, we suggest a corresponding constraint',
#    'code_for_constraint': '.isNonNegative("powerPs")'},
#   {'constraint_name': 'CompletenessConstraint(Completeness(powerPs,None))',
#    'column_name': 'powerPs',
#    'current_value': 'Completeness: 0.9999733290659839',
#    'description': "'powerPs' has less than 1% missing values",
#    'suggesting_rule': 'RetainCompletenessRule()',
#    'rule_description': 'If a column is incomplete in the sample, we model its completeness as a binomial variable, estimate a confidence interval and use this to define a lower bound for the completeness',
#    'code_for_constraint': '.hasCompleteness("powerPs", lambda x: x >= 0.99, "It should be above 0.99!")'}]}

# %% [markdown]
# ##### [TODO] import the JSON object to a DF to facilitate its processing

# %% [markdown]
# #### constraint verification

# %%
from pydeequ.checks import *
from pydeequ.verification import *

check = Check(spark, CheckLevel.Warning, "Review Check")

checkResult = VerificationSuite(spark) \
    .onData(_data) \
    .addCheck(
        check
        .isComplete('price')  \
        .isNonNegative('price')  \
        .isUnique('seller'))\
    .run()

# %%
checkResult_df = VerificationResult.checkResultsAsDataFrame(spark, checkResult)
checkResult_df.show()#truncate=False)
# Out:
# +------------+-----------+------------+--------------------+-----------------+--------------------+
# |       check|check_level|check_status|          constraint|constraint_status|  constraint_message|
# +------------+-----------+------------+--------------------+-----------------+--------------------+
# |Review Check|    Warning|     Warning|CompletenessConst...|          Failure|Value: 0.99997332...|
# |Review Check|    Warning|     Warning|ComplianceConstra...|          Success|                    |
# |Review Check|    Warning|     Warning|UniquenessConstra...|          Failure|Value: 2.66716453...|
# +------------+-----------+------------+--------------------+-----------------+--------------------+
